# %%
from gmm_sampler import *
import matplotlib.pyplot as plt
% matplotlib inline

# %%
data = gaussian_mixture_circle(batchsize=500, num_cluster=8, scale=2, std=0.2)
plt.plot(data.T[0], data.T[1], 'o')
plt.show()

# %%
data = gaussian_mixture_circle(batchsize=500, num_cluster=8, scale=2, std=0.5)
plt.plot(data.T[0], data.T[1], 'o')
plt.show()

# %%
data = gaussian_mixture_circle(batchsize=500, num_cluster=8, scale=2, std=0.375)
plt.plot(data.T[0], data.T[1], 'o')
plt.show()

# %%
data = gaussian_mixture_circle(batchsize=500, num_cluster=4, scale=2, std=0.5)
plt.plot(data.T[0], data.T[1], 'o')
plt.show()

# %%
data = gaussian_mixture_circle(batchsize=500, num_cluster=2, scale=2, std=0.2)
plt.plot(data.T[0], data.T[1], 'o')
plt.show()

# %%
data = gaussian_mixture_circle(batchsize=500, num_cluster=2, scale=2, std=0.5)
plt.plot(data.T[0], data.T[1], 'o')
plt.show()

# %%
data = gaussian_mixture_circle(batchsize=500, num_cluster=8, scale=2, std=0.1)
plt.plot(data.T[0], data.T[1], 'o')
plt.show()
